# %%
import random
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from datasets import load_dataset

# %%
#pipeline
ds = load_dataset("papluca/language-identification")
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Active compute device: {device}")

def tokenize(text):
    return text.lower().replace.split()

train_data = [(item["label"], item["text"]) for item in ds["train"]]
test_data = [(item["label"], item["text"]) for item in ds["test"]]
print(f"Sample review 0 text snippet: {train_data[0][1]}...")
